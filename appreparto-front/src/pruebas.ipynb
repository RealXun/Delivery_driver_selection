# %% [markdown]
# # A Jupyter file to do some code tests

# %% [markdown]
# ## get infro de database directly

# %%
import boto3
from botocore.exceptions import ClientError
def get_secret():

    secret_name = "AppRepartoDB"
    region_name = "eu-north-1"

    # Create a Secrets Manager client
    session = boto3.session.Session()
    client = session.client(
        service_name='secretsmanager',
        region_name=region_name
    )

    try:
        get_secret_value_response = client.get_secret_value(
            SecretId=secret_name
        )
    except ClientError as e:
        # For a list of exceptions thrown, see
        # https://docs.aws.amazon.com/secretsmanager/latest/apireference/API_GetSecretValue.html
        raise e

    # Decrypts secret using the associated KMS key.
    secret = get_secret_value_response['SecretString']

# %%
from dotenv import load_dotenv
import os
import psycopg2
load_dotenv()

# Get database credentials from environment variables
db_host = os.environ.get('PGSQL_HOST')
db_user = os.environ.get('PGSQL_USER')
db_password = os.environ.get('PGSQL_PASSWORD')
db_name = os.environ.get('PGSQL_DATABASE')

# Establish a connection to the database
conn = psycopg2.connect(
    host=db_host,
    user=db_user,
    password=db_password,
    database=db_name
)
cur = conn.cursor()
cur.execute("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public' ORDER BY table_name")
table_names = cur.fetchall()
cur.close()

for table_name in table_names:
    print(table_name[0])
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[1], line 13
#      10 db_name = os.environ.get('PGSQL_DATABASE')
#      12 # Establish a connection to the database
# ---> 13 conn = psycopg2.connect(
#      14     host=db_host,
#      15     user=db_user,
#      16     password=db_password,
#      17     database=db_name
#      18 )
#      19 cur = conn.cursor()
#      20 cur.execute("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public' ORDER BY table_name")
#
# File c:\Users\Chrisitan\miniconda3\envs\tripu\lib\site-packages\psycopg2\__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
# ...

# %%
cur = conn.cursor()
cur.execute("SELECT column_name FROM information_schema.columns WHERE table_name = 'clientes2'")
column_names = cur.fetchall()
cur.close()

for column_name in column_names:
    print(column_name[0])
# Out:
# id
# latitud
# longitud
# nombre
# email
# direccion

# %%
cur = conn.cursor()
cur.execute("SELECT * FROM clientes2")
clientes = cur.fetchall()
cur.close()

for cliente in clientes:
    print(cliente)
# Out:
# (1, 'Pedro', 'hudfiuhdsf@gmail.com', 'calle sinverguenzas', Decimal('40.452575'), Decimal('-3.616006'))
# (2, 'Juan', 'juan@gmail.com', 'Pl. Cronos, 5, 28037 Madrid, Spain', Decimal('40.439303'), Decimal('-3.619272'))

# %%
name_to_check = input("Enter the name to check: ")
print ("Searching for:",name_to_check)
cur = conn.cursor()
cur.execute("SELECT EXISTS(SELECT 1 FROM clientes2 WHERE nombre = %s)", (name_to_check,))
exists = cur.fetchone()[0]
cur.close()

if exists:
    print("Name exists in clientes2 table.")
else:
    print("Name does not exist in clientes2 table.")
# Out:
# Searching for: pedro
# Name does not exist in clientes2 table.

# %% [markdown]
# # create json example to get logins

# %%
import pandas as pd
# Create a sample DataFrame
users = pd.DataFrame({
    'name': ['David', 'Pepe', 'Maria'],
    'password': ['password123', 'password456', 'password789'],
    'type': ['user', 'admin', 'driver']
})

# Convert two columns of the DataFrame to a dictionary
my_dict = users[['name', 'password','type']].to_dict('records')

# Print the resulting dictionary
print(my_dict)
# Out:
# [{'name': 'David', 'password': 'password123', 'type': 'user'}, {'name': 'Pepe', 'password': 'password456', 'type': 'admin'}, {'name': 'Maria', 'password': 'password789', 'type': 'driver'}]

# %%
import json
# Convert the dictionary to a JSON string
json_string = json.dumps(my_dict)

# Print the resulting JSON string
json_string

# Save the dictionary as a JSON file
with open('users_logins.json', 'w') as f:
    json.dump(my_dict, f)

# %%
import json
# Load the JSON file into a dictionary
with open('users_logins.json', 'r') as f:
    my_dict = json.load(f)
# Print the resulting dictionary
print(my_dict)
# Out:
# [{'name': 'David', 'password': 'password123', 'type': 'user'}, {'name': 'Pepe', 'password': 'password456', 'type': 'admin'}, {'name': 'Maria', 'password': 'password789', 'type': 'driver'}]

# %%
username = 'user2'

if username not in my_dict:
    print(f'{username} not found')
# Out:
# user2 not found

# %%
import requests
data = requests.get("https://eogwk5ap22.execute-api.eu-north-1.amazonaws.com/Dev/clientes").json()
data
# Out:
# [{'id': 2,
#   'nombre': 'Juan',
#   'email': 'juan@gmail.com',
#   'direccion': 'Pl. Cronos, 5, 28037 Madrid, Spain',
#   'latitud': 40.439303,
#   'longitud': -3.619272},
#  {'id': 1,
#   'nombre': 'Pedro',
#   'email': 'hudfiuhdsf@gmail.com',
#   'direccion': 'calle sinverguenzas',
#   'latitud': 40.452575,
#   'longitud': -3.616006}]

# %% [markdown]
# # Dropbox

# %%
import pandas as pd
df = pd.read_csv("output.csv")
df.head(2)
# Out:
#                        id                    name phone      type  \
# 0  mClV8tidoTWjTJ2UAHfmcA                   Astor   NaN  armenian
# 1  OiBkdXLy5EF2lePHuticvQ  Restaurante Angel Mira   NaN  armenian
#
#                       address number  postal_code    city  \
# 0  Plaza de la Puerta del Sol   44.0        28013  Madrid
# 1  Plaza de la Puerta del Sol   58.0        28013  Madrid
#
#                                    full_address  latitude  longitude
# 0  Plaza de la Puerta del Sol, 44, 28013 Madrid  40.41676   -3.70385
# 1  Plaza de la Puerta del Sol, 58, 28013 Madrid  40.41676   -3.70385

# %%
def names_unique():
    '''
    Return a list of unique names in the column 'english_title'
    '''
    df = pd.read_csv("output.csv")
    df = df['type'].unique().tolist()
    return df
names_unique()
# Out:
# ['armenian',
#  'barbecue',
#  'fast food',
#  'french',
#  'ice cream parlor',
#  'italian',
#  'restaurant',
#  'latin american',
#  'mediterranean',
#  'mexican',
#  'pizza',
#  'seafood',
#  'spanish',
#  'steak house']

# %%
selected_name = st.selectbox("Choose the anime name",sorted(names_unique()))

# %%
    # Establish a database connection and create a cursor object
    cursor = conn.cursor()

    # Execute the query
    cursor.execute("SELECT tipo FROM comercios")
    results = cursor.fetchall()
    # Create a DataFrame from the results and specify the column names
    df = pd.DataFrame(results, columns=["Tipo"])

    # Display the DataFrame with column names using st.write()
    st.write("Resultados de la consulta:")
    st.write(df)

# %% [markdown]
# # Getting info from API

# %% [markdown]
# ## Clientes from API

# %%
import requests
import pandas as pd
def get_clientes_api():
    # Retrieve data from API endpoint and convert it to JSON
    data = requests.get("https://eogwk5ap22.execute-api.eu-north-1.amazonaws.com/Dev/clientes").json()
    # Create an empty list to store the dictionaries of pedidos
    clientes_list = []
    # Iterate over each pedido in the data and extract the relevant information into a dictionary
    for char in data:
        dict_clientes = {
            'id': char["id"] if char["id"] else None, # If id is present in the char dictionary, store its value. Otherwise, store None.
            'nombre': char["nombre"] if char["nombre"] else None, # If nombre is present in the char dictionary, store its value. Otherwise, store None.
            'email': char["email"] if char["email"] else None, # If email is present in the char dictionary, store its value. Otherwise, store None.
            'direccion': char["direccion"] if char["direccion"] else None, # If direccion is present in the char dictionary, store its value. Otherwise, store None.
            'latitud': char["latitud"] if char["latitud"] else None, # If latitud is present in the char dictionary, store its value. Otherwise, store None.
            'longitud': char["longitud"] if char["longitud"] else None # If longitud is present in the char dictionary, store its value. Otherwise, store None.
        }
        # Add the dictionary of pedidos to the list of pedidos
        clientes_list.append(dict_clientes)
    # Return the list of pedidos dictionaries
    return clientes_list
df_clientes = pd.DataFrame(get_clientes_api())

# %%
df_clientes.head(5)
# Out:
#      id                  nombre                            email  \
# 0  8831    Aarón Cepeda Portero    aaron.cepeda.portero@mail.com
# 1    32    Aarón Coloma Paredes    aaron.coloma.paredes@mail.com
# 2  7615  Aarón Dueñas Hernandez  aaron.dueñas.hernandez@mail.com
# 3  2214            Aarón Falcón            aaron.falcon@mail.com
# 4  3300    Aarón Paredes Romero    aaron.paredes.romero@mail.com
#
#                                 direccion    latitud   longitud
# 0            Calle de Ferraz, 116, Madrid  40.432410  40.432410
# 1  Calle de la Estrella Polar, 24, Madrid  40.410807  40.410807
# 2      Avenida de Peña Prieta, 34, Madrid  40.400243  40.400243
# 3    Avenida del Mediterráneo, 21, Madrid  40.407388  40.407388
# 4       Calle de la Cava Alta, 13, Madrid  40.412260  40.412260

# %% [markdown]
# ## Pedidos from API

# %%
import requests
import pandas as pd
def get_pedidos_api():
    # Retrieve data from API endpoint and convert it to JSON
    data = requests.get("https://eogwk5ap22.execute-api.eu-north-1.amazonaws.com/Dev/pedidos").json()
    # Create an empty list to store the dictionaries of pedidos
    pedidos_list = []
    # Iterate over each pedido in the data and extract the relevant information into a dictionary
    for char in data:
        dict_pedidos = {
            'id_pedido': char["id_pedido"] if char["id_pedido"] else None, # If id_pedido is present in the char dictionary, store its value. Otherwise, store None.
            'id_cliente': char["id_cliente"] if char["id_cliente"] else None, # If id_cliente is present in the char dictionary, store its value. Otherwise, store None.
            'id_comercio': char["id_comercio"] if char["id_comercio"] else None, # If id_comercio is present in the char dictionary, store its value. Otherwise, store None.
            'id_repartidor': char["id_repartidor"] if char["id_repartidor"] else None, # If id_repartidor is present in the char dictionary, store its value. Otherwise, store None.
            'latitud': char["latitud"] if char["latitud"] else None, # If latitud is present in the char dictionary, store its value. Otherwise, store None.
            'longitud': char["longitud"] if char["longitud"] else None, # If longitud is present in the char dictionary, store its value. Otherwise, store None.
            'datetime_pedido': char["datetime_pedido"] if char["datetime_pedido"] else None, # If datetime_pedido is present in the char dictionary, store its value. Otherwise, store None.
            'tamaño': char["tamaño"] if char["tamaño"] else None, # If tamaño is present in the char dictionary, store its value. Otherwise, store None.
            'status': char["status"]  if char["status"] else None, # If status is present in the char dictionary, store its value. Otherwise, store None.
            'direccion': char["direccion"]  if char["direccion"] else None # If direccion is present in the char dictionary, store its value. Otherwise, store None.
        }
        # Add the dictionary of pedidos to the list of pedidos
        pedidos_list.append(dict_pedidos)
    # Return the list of pedidos dictionaries
    return pedidos_list
df_pedidos = pd.DataFrame(get_pedidos_api())

# %%
df_pedidos_recibidos = pd.DataFrame(get_pedidos_api())
df_pedidos_recibidos
# Out:
#       id_pedido  id_cliente  id_comercio  id_repartidor    latitud  longitud  \
# 0             1           1          367            NaN  40.441461 -3.650346
# 1             2           1          386            NaN  40.441461 -3.650346
# 2             3           1          325            NaN  40.441461 -3.650346
# 3             4           1          376            NaN  40.441461 -3.650346
# 4             5           1           28            NaN  40.441461 -3.650346
# ...         ...         ...          ...            ...        ...       ...
# 1463       1465           1          823            NaN  40.441461 -3.650346
# 1464       1466           1          823            NaN  40.441461 -3.650346
# 1465       1467           1          823            NaN  40.441461 -3.650346
# 1466       1468           1          823            NaN  40.441461 -3.650346
# 1467       1469           1          823            NaN  40.441461 -3.650346
#
# ...

# %%
df_pedidos_recibidos[df_pedidos_recibidos["id_pedido"] == 1464]
# Out:
#       id_pedido  id_cliente  id_comercio  id_repartidor    latitud  longitud  \
# 1462       1464           1          823            NaN  40.441461 -3.650346
#
#           datetime_pedido  tamaño    status                         direccion
# 1462  2023-03-28 14:13:13    0.79  Recibido  Calle de Torrelaguna, 16, Madrid

# %%
# Create a pandas dataframe
df_pedidos_recibidos = pd.DataFrame(get_pedidos_api())
id_comercio = 823
df_pedidos_recibidos = df_pedidos_recibidos[df_pedidos_recibidos['id_comercio'] == id_comercio]
df_pedidos_recibidos = df_pedidos_recibidos[df_pedidos_recibidos['status'] == "Recibido"]
df_pedidos_recibidos = df_pedidos_recibidos[['id_pedido', 'status', 'datetime_pedido']]
df_pedidos_recibidos = df_pedidos_recibidos.rename(columns={'id_pedido': 'ID Pedido', 'status': 'Estado', 'datetime_pedido': 'Fecha Pedido'})
df_pedidos_recibidos = df_pedidos_recibidos.sort_values(by=['ID Pedido'], ascending=True)
df_pedidos_recibidos
# Out:
#       ID Pedido    Estado         Fecha Pedido
# 1462       1464  Recibido  2023-03-28 14:13:13
# 1463       1465  Recibido  2023-03-28 14:13:13
# 1467       1469  Recibido  2023-03-28 20:30:51

# %%
df_pedidos_recibidos = pd.DataFrame(get_pedidos_api())
# Create a pandas dataframe
df_pedidos_recibidos = df_pedidos_recibidos[['id_pedido', 'status', 'datetime_pedido']]

# Define a dictionary of column name mappings
column_names = {
    'id_pedido': 'ID Pedido',
    'status': 'Estado',
    'id_cliente': 'Customer ID',
    'id_comercio': 'Store ID',
    'id_repartidor': 'Driver ID',
    'direccion': 'Address',
    'datetime_pedido': 'Fecha Pedido',
    'tamaño': 'Size'
}

df_pedidos_recibidos = df_pedidos_recibidos.rename(columns=column_names)
    
selected_columns = ['ID Pedido', 'Estado', 'Fecha Pedido']
df_pedidos_recibidos = df_pedidos_recibidos[selected_columns]
df_pedidos_recibidos = df_pedidos_recibidos.sort_values(by=['ID Pedido'], ascending=True)
# reset the index and remove the original index column
df_pedidos_recibidos = df_pedidos_recibidos.reset_index(drop=True)    
df_pedidos_recibidos.set_index('ID Pedido')
df_pedidos_recibidos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 2
#       1 df_pedidos_recibidos = pd.DataFrame(get_pedidos_api())
# ----> 2 df_pedidos_recibidos = df_pedidos_recibidos.rename(columns=column_names)
#       4 selected_columns = ['ID Pedido', 'Estado', 'Fecha Pedido']
#       5 df_pedidos_recibidos = df_pedidos_recibidos[selected_columns]
#
# NameError: name 'column_names' is not defined

# %%
df_pedidos
# Out:
#       id_pedido  id_cliente  id_comercio  id_repartidor    latitud  longitud  \
# 0             1           1          367            NaN  40.441461 -3.650346
# 1             2           1          386            NaN  40.441461 -3.650346
# 2             3           1          325            NaN  40.441461 -3.650346
# 3             4           1          376            NaN  40.441461 -3.650346
# 4             5           1           28            NaN  40.441461 -3.650346
# ...         ...         ...          ...            ...        ...       ...
# 1463       1465           1          823            NaN  40.441461 -3.650346
# 1464       1466           1          823            NaN  40.441461 -3.650346
# 1465       1467           1          823            NaN  40.441461 -3.650346
# 1466       1468           1          823            NaN  40.441461 -3.650346
# 1467       1469           1          823            NaN  40.441461 -3.650346
#
# ...

# %%
df_pedidos.columns
# Out:
# Index(['id_pedido', 'id_cliente', 'id_comercio', 'id_repartidor', 'latitud',
#        'longitud', 'datetime_pedido', 'tamaño', 'status', 'direccion'],
#       dtype='object')

# %%
df_pedidos.head(210)
# Out:
#      id_pedido  id_cliente  id_comercio  id_repartidor    latitud  longitud  \
# 0            1           1          367            NaN  40.441461 -3.650346
# 1            2           1          386            NaN  40.441461 -3.650346
# 2            3           1          325            NaN  40.441461 -3.650346
# 3            4           1          376            NaN  40.441461 -3.650346
# 4            5           1           28            NaN  40.441461 -3.650346
# ..         ...         ...          ...            ...        ...       ...
# 205        206           1          823            8.0  40.441461 -3.650346
# 206        207          38           22            NaN  40.420010 -3.698140
# 207        208          36           24            NaN  40.411450 -3.707680
# 208        209          16            1            NaN  40.416760 -3.703850
# 209        210          16           99            NaN  40.415790 -3.707990
#
#          datetime_pedido  tamaño       status  \
# ...

# %% [markdown]
# ## Comercios from API

# %%
import requests
import pandas as pd
def get_comercios_api():
    # Use the requests library to send a GET request to the API endpoint and receive JSON data in response
    data = requests.get("https://eogwk5ap22.execute-api.eu-north-1.amazonaws.com/Dev/comercios").json()

    # Create an empty list to store the formatted data
    comer_list = []

    # Loop through each dictionary in the received data and format it into a new dictionary with desired keys
    for char in data:
        dict_comer = {'id': char["id"],
                    'nombre': char["nombre"],
                    'zona': char["zona"],
                    'direccion': char["direccion"],
                    'tipo': char["tipo"],
                    'latitud': char["latitud"],
                    'longitud': char["longitud"]
                    }

        # Append the new dictionary to the list
        comer_list.append(dict_comer)

    # Return the list of formatted dictionaries
    return comer_list
df_comercios = pd.DataFrame(get_comercios_api())

# %%
df_comercios.shape
# Out:
# (1133, 7)

# %%
filtered_df = df_comercios[df_comercios["tipo"] == "Pizza"]
filtered_df
# Out:
#       id                     nombre   zona  \
# 799  800                      Jaleo  28013
# 800  801         Pizzería El Trébol  28012
# 801  802              Tortuga Pizza  28012
# 802  803  Oven Mozzarella Preciados  28013
# 803  804     Mad Gourmets Canalejas  28014
# ..   ...                        ...    ...
# 876  877       Mastropiero Pizzeria  28004
# 877  878          Grosso Napoletano  28012
# 878  879                    Papizza  28004
# 879  880                   Nebraska  28015
# 880  881        Pizzería Maravillas  28004
#
#                                    direccion   tipo   latitud  longitud
# 799                   Calle Mayor, 4, Madrid  Pizza  40.41651  -3.70499
# 800           Calle de Barcelona, 13, Madrid  Pizza  40.41512  -3.70256
# 801        Calle de Espoz y Mina, 11, Madrid  Pizza  40.41529  -3.70232
# 802           Calle de Preciados, 11, Madrid  Pizza  40.41853  -3.70501
# 803              Calle de Alcalá, 12, Madrid  Pizza  40.41743  -3.70093
# ...

# %%
df_comercios.head(10)
# Out:
#    id                  nombre   zona                               direccion  \
# 0   1                   Astor  28013  Plaza de la Puerta del Sol, 44, Madrid
# 1   2  Restaurante Angel Mira  28013  Plaza de la Puerta del Sol, 58, Madrid
# 2   3       Cafetería Armenia  28013             Calle del Carmen, 3, Madrid
# 3   4                   Oroya  28013           Plaza del Celenque, 2, Madrid
# 4   5             Pe de Pisco  28013           Calle de la Aduana, 5, Madrid
# 5   6           La Cachiterie  28013         Calle de la Montera, 33, Madrid
# 6   7            Bolus Burger  28013   Calle de Mesonero Romanos, 12, Madrid
# 7   8     Entre Pisco y Nazca  28012       Calle de Espoz y Mina, 32, Madrid
# 8   9       Mix&Me Bar Madrid  28012        Calle de las Huertas, 52, Madrid
# 9  10                  Lupita  28013       Calle de los Jardines, 21, Madrid
#
#        tipo   latitud  longitud
# 0  Armenian  40.41676  -3.70385
# 1  Armenian  40.41676  -3.70385
# ...

# %% [markdown]
# ## Repartidores from API

# %%
import requests
import pandas as pd
def get_repartidores_api():
    # Get the data from the specified URL and save it in JSON format
    data = requests.get("https://eogwk5ap22.execute-api.eu-north-1.amazonaws.com/Dev/repartidores").json()
    # Create an empty list to hold the driver details
    repartidores_list = []
    # Loop through each driver in the retrieved data and extract the relevant information
    for char in data:
        dict_repartidores = {'id': char["id"],
                    'nombre': char["unombre"] if char["unombre"] else None,
                    'email': char["email"] if char["email"] else None,
                    'status': char["status"] if char["status"] else None,
                    'vehiculo': char["vehiculo"] if char["vehiculo"] else None,
                    'ocupado': char["ocupado"] if char["ocupado"] else None,
                    'zona': char["zona"] if char["zona"] else None,
                    'latitud': char["latitud"] if char["latitud"] else None,
                    'longitud': char["longitud"] if char["longitud"] else None,
                    'datetime_ult_act': char["datetime_ult_act"]  if char["datetime_ult_act"] else None
                    }
        # Add the extracted driver details to the list
        repartidores_list.append(dict_repartidores)
    # Return the list of driver details
    return repartidores_list
df_repartidores = pd.DataFrame(get_repartidores_api())

# %%
df_repartidores.head(20)
# Out:
#     id                          nombre  \
# 0    1             Cipriano Reig Galán
# 1    2             Lucas Salgado Leiva
# 2    3           Valentina Pol Estrada
# 3    4                   Gastón Varela
# 4    5     Guadalupe Iglesia Sarmiento
# 5    6         Milagros Adán Calatayud
# 6    7              César Barrio-Lucas
# 7    8           Ramiro Gonzalo Murcia
# 8    9                   Aura de López
# 9   10                Roxana Gallo Pla
# 10  11                Dionisia de Rosa
# 11  12       Maristela Royo Villalobos
# 12  13           Sebastian Vidal Benet
# 13  14               Julio del Carmona
# 14  15        Pacífica Castejón Tolosa
# 15  16        Goyo Tadeo Pomares Roman
# 16  17             Tomasa Baena Blanco
# 17  18  Francisco Javier Estrada Cerdá
# 18  19    Jennifer Perlita Jaume Juliá
# 19  20                 Carlota Aguilar
#
#                                       email status     vehiculo ocupado  zona  \
# ...

# %% [markdown]
# # Creating some orders using information from our Db

# %% [markdown]
# ### Creando numeros random

# %%
# Creando numeros random
import random
id_cliente = []
id_comercio = []

for i in range(20, 201):
    
    cliente = random.randint(1, 50)
    id_cliente.append(cliente)
    
    comercio  = random.randint(1, 500)
    id_comercio.append(comercio)

status = ["Entregado" for i in range(20, 201)]
id_pedido = list(range(20, 201))

# %% [markdown]
# ### Obteniendo latitud y longitud de los id de comercio

# %%
# example list of commerce IDs
id_comercio

coordenadas = []
for id in id_comercio:
    latitud = df_comercios.loc[df_comercios['id'] == id, 'latitud'].iloc[0]
    longitud = df_comercios.loc[df_comercios['id'] == id, 'longitud'].iloc[0]
    coordenadas.append((latitud, longitud))
# Use list comprehension to separate latitud and longitud into separate lists
latitud, longitud = [list(coord) for coord in zip(*coordenadas)]

# %% [markdown]
# ### Obteniendo direccion del cliente acorde al id

# %%
# example list of commerce IDs
id_cliente

# Crear una lista vacía para almacenar las direcciones correspondientes
direcciones = []

# Iterar sobre los valores de id_cliente
for id in id_cliente:
    # Verificar si el valor está presente en la columna 'id' de df_clientes
    if id in df_clientes['id'].values:
        # Si es así, seleccionar la fila correspondiente y obtener el valor de la columna 'direccion'
        direccion = df_clientes.loc[df_clientes['id'] == id, 'direccion'].values[0]
        # Agregar la dirección a la lista
        direcciones.append(direccion)
    else:
        # Si no hay una coincidencia, agregar un valor nulo a la lista
        direcciones.append(None)

# %% [markdown]
# ### Obteniendo resto de datos

# %%
from datetime import datetime, timedelta

datetime_pedido = []
now = datetime.now()

for i in range(20, 201):
    date_time_str = (now - timedelta(days=i)).strftime('%Y-%m-%d %H:%M:%S')
    datetime_pedido.append(date_time_str)

# %%
import random

random.seed(1234)
tamaño = []

for i in range(20, 201):
    tamaño_ = round(random.uniform(0.2, 2), 2)
    tamaño.append(tamaño_)
tamaño
# Out:
# [1.94,
#  0.99,
#  0.21,
#  1.84,
#  1.89,
#  1.25,
#  1.41,
#  0.35,
#  1.58,
#  0.63,
#  0.26,
#  1.62,
#  0.82,
#  1.32,
#  1.31,
#  0.47,
#  0.53,
#  0.41,
#  0.23,
#  1.08,
#  1.94,
#  0.32,
#  1.17,
#  1.04,
#  1.28,
#  0.36,
#  1.24,
#  0.69,
#  1.2,
#  1.36,
#  1.07,
#  0.84,
#  0.65,
#  1.88,
#  1.02,
#  1.15,
#  0.23,
#  1.11,
#  0.21,
#  0.46,
#  1.05,
#  0.88,
#  0.3,
#  1.26,
#  0.5,
#  1.2,
#  0.46,
#  1.89,
#  1.59,
#  1.92,
#  0.45,
#  0.75,
#  0.27,
#  0.7,
#  1.65,
#  0.52,
#  0.48,
#  1.92,
#  0.48,
#  1.7,
#  0.27,
#  0.9,
#  0.83,
#  0.82,
#  1.67,
#  1.06,
#  1.61,
#  1.05,
#  1.67,
#  1.79,
#  0.99,
#  1.61,
#  1.67,
#  0.73,
#  0.42,
#  0.53,
#  0.98,
#  0.42,
#  1.15,
#  1.69,
#  1.07,
#  1.67,
#  1.38,
#  1.35,
#  0.82,
#  1.46,
#  1.66,
#  0.48,
#  1.83,
#  0.68,
#  0.48,
#  1.71,
#  1.5,
#  1.63,
#  1.0,
#  0.33,
#  0.91,
#  0.29,
#  0.72,
#  0.27,
#  1.11,
#  0.36,
#  1.88,
#  1.46,
#  0.77,
#  1.9,
#  0.32,
#  0.66,
#  0.33,
#  0.97,
#  0.56,
#  0.91,
# ...

# %%
status = []

for i in range(20, 201):
    status_ = "Entregado"
    status.append(status_)

# %%
print(len(latitud)) 
print(len(longitud)) 
print(len(direcciones)) 
print(len(id_cliente)) 
print(len(id_comercio)) 
print(len(datetime_pedido)) 
print(len(status)) 
print(len(tamaño))
# Out:
# 181
# 181
# 181
# 181
# 181
# 181
# 181
# 181

# %%
from datetime import datetime
import random
import psycopg2
import pandas as pd

# Get database credentials from environment variables
db_host2 = "appreparto-db.c0ttdmuj4kco.eu-north-1.rds.amazonaws.com"
db_user2 = "durumkebab"
db_password2 = "Qu3l3ch35353l5h4w4rm4!"
db_database2 = "repartos_test"

# Establish a connection to the database
conn = psycopg2.connect(
    host=db_host2,
    user=db_user2,
    password=db_password2,
    database=db_database2)

# Establish a database connection and create a cursor object
cursor = conn.cursor()

# %% [markdown]
# ## adding information to the db

# %%
# Iterar sobre los valores y ejecutar la consulta SQL
latitud
longitud
direcciones
id_cliente
id_comercio
datetime_pedido
tamaño
status
for i in range(1, 181):
    cursor.execute("INSERT INTO pedidos (latitud, longitud, direccion, id_cliente, id_comercio, datetime_pedido, tamaño, status) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)",(latitud[i], longitud[i], direcciones[i], id_cliente[i], id_comercio[i], datetime_pedido[i], tamaño[i], status[i]))

# Confirmar los cambios y cerrar la conexión
conn.commit()
conn.close()

# %% [markdown]
# # Find closest drivers using KNN

# %%
import requests
import pandas as pd
def get_repartidores_api():
    # Get the data from the specified URL and save it in JSON format
    data = requests.get("https://eogwk5ap22.execute-api.eu-north-1.amazonaws.com/Dev/repartidores").json()
    # Create an empty list to hold the driver details
    repartidores_list = []
    # Loop through each driver in the retrieved data and extract the relevant information
    for char in data:
        dict_repartidores = {'id': char["id"],
                    'nombre': char["unombre"] if char["unombre"] else None,
                    'email': char["email"] if char["email"] else None,
                    'status': char["status"] if char["status"] else None,
                    'vehiculo': char["vehiculo"] if char["vehiculo"] else None,
                    'ocupado': char["ocupado"] if char["ocupado"] else None,
                    'zona': char["zona"] if char["zona"] else None,
                    'latitud': char["latitud"] if char["latitud"] else None,
                    'longitud': char["longitud"] if char["longitud"] else None,
                    'datetime_ult_act': char["datetime_ult_act"]  if char["datetime_ult_act"] else None
                    }
        # Add the extracted driver details to the list
        repartidores_list.append(dict_repartidores)
    # Return the list of driver details
    return repartidores_list
df_repartidores = pd.DataFrame(get_repartidores_api())
df_repartidores.head(10)
# Out:
#    id                       nombre                                 email  \
# 0   1          Cipriano Reig Galán          cipriano.reig.galan@mail.com
# 1   2          Lucas Salgado Leiva          lucas.salgado.leiva@mail.com
# 2   3        Valentina Pol Estrada        valentina.pol.estrada@mail.com
# 3   4                Gastón Varela                gaston.varela@mail.com
# 4   5  Guadalupe Iglesia Sarmiento  guadalupe.iglesia.sarmiento@mail.com
# 5   6      Milagros Adán Calatayud      milagros.adan.calatayud@mail.com
# 6   7           César Barrio-Lucas           cesar.barrio-lucas@mail.com
# 7   8        Ramiro Gonzalo Murcia        ramiro.gonzalo.murcia@mail.com
# 8   9                Aura de López                aura.de.lopez@mail.com
# 9  10             Roxana Gallo Pla             roxana.gallo.pla@mail.com
#
#   status     vehiculo ocupado  zona    latitud  longitud datetime_ult_act
# 0   True  Motocicleta    None  None  40.489035 -3.691452             None
# ...

# %%
df_repartidores = df_repartidores[df_repartidores['status'] == True]
df_repartidores
# Out:
#       id                       nombre                                 email  \
# 0      1          Cipriano Reig Galán          cipriano.reig.galan@mail.com
# 1      2          Lucas Salgado Leiva          lucas.salgado.leiva@mail.com
# 2      3        Valentina Pol Estrada        valentina.pol.estrada@mail.com
# 3      4                Gastón Varela                gaston.varela@mail.com
# 4      5  Guadalupe Iglesia Sarmiento  guadalupe.iglesia.sarmiento@mail.com
# ..   ...                          ...                                   ...
# 473  474   Estrella Oliveras Fábregas   estrella.oliveras.fabregas@mail.com
# 482  483           Lidia Lago Montaña           lidia.lago.montaña@mail.com
# 484  485          Arcelia de Expósito          arcelia.de.exposito@mail.com
# 486  487        Epifanio Jódar Ibarra        epifanio.jodar.ibarra@mail.com
# 495  496             Nacio del Millán             nacio.del.millan@mail.com
#
# ...

# %%
df_repartidores = pd.DataFrame(get_repartidores_api())
df_repartidores = df_repartidores[(df_repartidores['status'] == True) & (df_repartidores['ocupado'] != True)]
df_repartidores
# Out:
#       id                      nombre                                email  \
# 0      1         Cipriano Reig Galán         cipriano.reig.galan@mail.com
# 2      3       Valentina Pol Estrada       valentina.pol.estrada@mail.com
# 5      6     Milagros Adán Calatayud     milagros.adan.calatayud@mail.com
# 6      7          César Barrio-Lucas          cesar.barrio-lucas@mail.com
# 12    13       Sebastian Vidal Benet       sebastian.vidal.benet@mail.com
# ..   ...                         ...                                  ...
# 473  474  Estrella Oliveras Fábregas  estrella.oliveras.fabregas@mail.com
# 482  483          Lidia Lago Montaña          lidia.lago.montaña@mail.com
# 484  485         Arcelia de Expósito         arcelia.de.exposito@mail.com
# 486  487       Epifanio Jódar Ibarra       epifanio.jodar.ibarra@mail.com
# 495  496            Nacio del Millán            nacio.del.millan@mail.com
#
#     status     vehiculo ocupado  zona    latitud  longitud datetime_ult_act
# ...

# %%
import requests
import pandas as pd
def get_pedidos_api():
    # Retrieve data from API endpoint and convert it to JSON
    data = requests.get("https://eogwk5ap22.execute-api.eu-north-1.amazonaws.com/Dev/pedidos").json()
    # Create an empty list to store the dictionaries of pedidos
    pedidos_list = []
    # Iterate over each pedido in the data and extract the relevant information into a dictionary
    for char in data:
        dict_pedidos = {
            'id_pedido': char["id_pedido"] if char["id_pedido"] else None, # If id_pedido is present in the char dictionary, store its value. Otherwise, store None.
            'id_cliente': char["id_cliente"] if char["id_cliente"] else None, # If id_cliente is present in the char dictionary, store its value. Otherwise, store None.
            'id_comercio': char["id_comercio"] if char["id_comercio"] else None, # If id_comercio is present in the char dictionary, store its value. Otherwise, store None.
            'id_repartidor': char["id_repartidor"] if char["id_repartidor"] else None, # If id_repartidor is present in the char dictionary, store its value. Otherwise, store None.
            'latitud': char["latitud"] if char["latitud"] else None, # If latitud is present in the char dictionary, store its value. Otherwise, store None.
            'longitud': char["longitud"] if char["longitud"] else None, # If longitud is present in the char dictionary, store its value. Otherwise, store None.
            'datetime_pedido': char["datetime_pedido"] if char["datetime_pedido"] else None, # If datetime_pedido is present in the char dictionary, store its value. Otherwise, store None.
            'tamaño': char["tamaño"] if char["tamaño"] else None, # If tamaño is present in the char dictionary, store its value. Otherwise, store None.
            'status': char["status"]  if char["status"] else None, # If status is present in the char dictionary, store its value. Otherwise, store None.
            'direccion': char["direccion"]  if char["direccion"] else None # If direccion is present in the char dictionary, store its value. Otherwise, store None.
        }
        # Add the dictionary of pedidos to the list of pedidos
        pedidos_list.append(dict_pedidos)
    # Return the list of pedidos dictionaries
    return pedidos_list
df_pedidos = pd.DataFrame(get_pedidos_api())

# %%
selected_columns = ['id_pedido', 'status','id_repartidor', 'id_cliente', 'id_comercio', 'direccion', 'datetime_pedido', 'tamaño']
df_selected = df_pedidos[selected_columns]
df_selected = df_selected.sort_values(by=['id_pedido'], ascending=True)
df_selected = df_selected[df_selected['id_comercio'] == 823]

# %%
df_selected
# Out:
#       id_pedido          status  id_repartidor  id_cliente  id_comercio  \
# 9            10     {Preparado}            NaN           1          823
# 10           11  {"En Reparto"}            NaN           1          823
# 11           12     {Entregado}            NaN           1          823
# 12           13     {Entregado}            NaN           1          823
# 13           14       Entregado            8.0           1          823
# 14           15       Entregado            NaN           1          823
# 15           16      En reparto            NaN           1          823
# 16           17       Entregado            NaN           1          823
# 17           18       Entregado            8.0           1          823
# 18           19       Entregado            NaN           1          823
# 19           20      En reparto            NaN           1          823
# 20           21      En Reparto            NaN           1          823
# ...

# %%
df_selected_Recibido = df_selected[df_selected['status'] == "Recibido"]
df_selected_Recibido
# Out:
#       id_pedido    status  id_repartidor  id_cliente  id_comercio  \
# 1456       1458  Recibido            NaN           1          823
# 1457       1459  Recibido            NaN           1          823
# 1458       1460  Recibido            NaN           1          823
# 1459       1461  Recibido            NaN           1          823
# 1460       1462  Recibido            NaN           1          823
# 1461       1463  Recibido            NaN           1          823
# 1462       1464  Recibido            NaN           1          823
# 1463       1465  Recibido            NaN           1          823
# 1464       1466  Recibido            NaN           1          823
# 1465       1467  Recibido            NaN           1          823
# 1466       1468  Recibido            NaN           1          823
#
#                              direccion      datetime_pedido  tamaño
# 1456  Calle de Torrelaguna, 16, Madrid  2023-03-28 14:13:10    1.57
# ...

# %%
df_selected_Recibido_pedido = df_selected_Recibido[df_selected_Recibido['id_pedido'] == 1458]
df_selected_Recibido_pedido
# Out:
#       id_pedido    status  id_repartidor  id_cliente  id_comercio  \
# 1456       1458  Recibido            NaN           1          823
#
#                              direccion      datetime_pedido  tamaño
# 1456  Calle de Torrelaguna, 16, Madrid  2023-03-28 14:13:10    1.57

# %%
import requests
import pandas as pd
def get_comercios_api():
    # Use the requests library to send a GET request to the API endpoint and receive JSON data in response
    data = requests.get("https://eogwk5ap22.execute-api.eu-north-1.amazonaws.com/Dev/comercios").json()

    # Create an empty list to store the formatted data
    comer_list = []

    # Loop through each dictionary in the received data and format it into a new dictionary with desired keys
    for char in data:
        dict_comer = {'id': char["id"],
                    'nombre': char["nombre"],
                    'zona': char["zona"],
                    'direccion': char["direccion"],
                    'tipo': char["tipo"],
                    'latitud': char["latitud"],
                    'longitud': char["longitud"]
                    }

        # Append the new dictionary to the list
        comer_list.append(dict_comer)

    # Return the list of formatted dictionaries
    return comer_list
df_comercios = pd.DataFrame(get_comercios_api())
df_comercios = df_comercios[df_comercios['id'] == 823]
df_comercios
# Out:
#       id         nombre   zona                          direccion   tipo  \
# 822  823  Antonia Pizza  28004  Calle de las Infantas, 14, Madrid  Pizza
#
#      latitud  longitud
# 822  40.4208  -3.69998

# %%
from sklearn.neighbors import NearestNeighbors
import numpy as np

'''
This code calculates the Manhattan distance between a shop and a set of delivery drivers, 
and then uses the NearestNeighbors algorithm to find the closest driver to the shop. 
The ID of the closest driver is then retrieved from the dataset of delivery drivers.
'''
def find_driver(id_comer):

    df_comercios = pd.DataFrame(get_comercios_api())
    print("df_comercios")
    df_comercios = df_comercios[df_comercios['id'] == id_comer]
    print("df_comercios2")
    df_repartidores = pd.DataFrame(get_repartidores_api())
    print("df_repartidores")
    df_repartidores = df_repartidores[(df_repartidores['status'] == True) & (df_repartidores['ocupado'] != True)]
    print("df_repartidores2")
    # Get the latitude and longitude of the shop from the first row of the df_comercios DataFrame
    shop_lat = df_comercios["latitud"].values[0]
    print("df_repartidores2")
    shop_lon = df_comercios["longitud"].values[0]
    print("df_repartidores2")

    # Calculate the Manhattan distance between each delivery driver and the shop using their latitudes and longitudes
    df_repartidores["manhattan_distance"] = np.abs(df_repartidores["latitud"] - shop_lat) + np.abs(df_repartidores["longitud"] - shop_lon)

    # Set the number of nearest neighbors to consider for the k-NN algorithm
    k = 1

    # Create a matrix X containing the latitude and longitude of each delivery driver
    X = df_repartidores[["latitud", "longitud"]]

    # add column names to X
    X.columns = ["latitud", "longitud"]

    # Reset the index of the df_repartidores DataFrame
    df_repartidores = df_repartidores.reset_index(drop=True)

    # Fit the k-NN model to the X matrix
    nbrs = NearestNeighbors(n_neighbors=k, algorithm='auto', metric='manhattan').fit(X)

    # Find the indices and distances of the k nearest neighbors to the shop location
    shop_location = [[shop_lat, shop_lon]]
    shop_location_df = pd.DataFrame(shop_location, columns=['latitud', 'longitud'])  # add column names to the shop location

    # Find the indices and distances of the k nearest neighbors to the shop location
    distances, indices = nbrs.kneighbors(shop_location_df)

    # Get the index of the closest driver from the indices array
    closest_driver_index = indices[0][0]

    # Get the ID of the closest driver from the df_repartidores DataFrame using the closest driver's index
    closest_driver_id = df_repartidores.loc[closest_driver_index, "id"]

    # Return the ID of the closest driver 
    return closest_driver_id

# %%
id_repartidor_closest = int(find_driver(823))
int(id_repartidor_closest)

# %% [markdown]
# # Google API to get districs from coodenadas

# %%
import requests
coordinates = list(zip(df_comercios["latitud"], df_comercios["longitud"]))
# Define Google Maps API endpoint and parameters
endpoint = "https://maps.googleapis.com/maps/api/geocode/json"
params = {
    "latlng": "",
    "result_type": "neighborhood",
    "key": "AIzaSyCN0rUDiJWNFRbEXW2DX81j_kiS6_rUYzg"
}

# Create empty list to store results
neighborhoods = []

# Loop over coordinates and send requests to Google Maps API
for lat, lng in coordinates:
    # Set latitude and longitude in parameters
    params["latlng"] = f"{lat},{lng}"

    # Send request to Google Maps API
    response = requests.get(endpoint, params=params)

    # Parse response to get neighborhood and add to list
    if response.ok:
        data = response.json()
        if data["results"]:
            neighborhood = data["results"][0]["address_components"][0]["long_name"]
            neighborhoods.append(neighborhood)
        else:
            neighborhoods.append(None)
    else:
        neighborhoods.append(None)

# Print list of neighborhoods
print(neighborhoods)
# Out:
# ['Sol', 'Sol', 'Sol', 'Sol', 'Sol', 'Sol', 'Sol', 'Barrio de las Letras', 'Barrio de las Letras', 'Sol', 'Sol', 'Sol', 'Embajadores', 'Palacio', 'Embajadores', 'Malasaña', 'Palacio', 'Palacio', 'Justicia', 'Justicia', 'Justicia', 'Justicia', 'Palacio', 'Embajadores', 'Cortes', 'Malasaña', 'Justicia', 'Barrio de La Latina', 'Justicia', 'Malasaña', 'Lavapiés', 'Gran Vía', 'Justicia', 'Malasaña', 'Malasaña', 'Embajadores', 'Palacio', 'Justicia', 'Justicia', 'Barrio de La Latina', 'Barrio de La Latina', 'Barrio de La Latina', 'Lavapiés', 'Malasaña', 'Lavapiés', 'Malasaña', 'Cortes', 'Embajadores', 'Malasaña', 'Justicia', 'Justicia', 'Justicia', 'Justicia', 'Lavapiés', 'Argüelles', 'Justicia', 'Imperial', 'Argüelles', 'Justicia', 'Malasaña', 'Justicia', 'Imperial', 'Malasaña', 'Malasaña', 'Palos de la Frontera', 'Trafalgar', 'Palos de la Frontera', 'Trafalgar', 'Las Acacias', 'Palos de la Frontera', 'Palos de la Frontera', 'Trafalgar', 'Trafalgar', 'Trafalgar', 'Trafalgar', 'Arapiles', 'G
# ...

# %% [markdown]
# # Añadir zona a las tablas desde coordenadas

# %%
import requests
def get_comercios_api():
    # Use the requests library to send a GET request to the API endpoint and receive JSON data in response
    data = requests.get("https://eogwk5ap22.execute-api.eu-north-1.amazonaws.com/Dev/comercios").json()

    # Create an empty list to store the formatted data
    comer_list = []

    # Loop through each dictionary in the received data and format it into a new dictionary with desired keys
    for char in data:
        dict_comer = {'id': char["id"],
                    'nombre': char["nombre"],
                    'zona': char["zona"],
                    'direccion': char["direccion"],
                    'tipo': char["tipo"],
                    'latitud': char["latitud"],
                    'longitud': char["longitud"]
                    }

        # Append the new dictionary to the list
        comer_list.append(dict_comer)

    # Return the list of formatted dictionaries
    return comer_list
# Create a pandas dataframe using data obtained from an API call to get driver information
df_comercios = pd.DataFrame(get_comercios_api())

# %%
df_comercios

# %% [markdown]
# # pedidos modelo getting the info

# %%
import os
from pathlib import Path
import psycopg2
import pandas as pd
from datetime import datetime
import random
import requests
from sklearn.neighbors import NearestNeighbors
import numpy as np

# Get database credentials from environment variables
db_host2 = "appreparto-db.c0ttdmuj4kco.eu-north-1.rds.amazonaws.com"
db_user2 = "durumkebab"
db_password2 = "Qu3l3ch35353l5h4w4rm4!"
db_database2 = "repartos_test"

# Establish a connection to the database
conn = psycopg2.connect(
    host=db_host2,
    user=db_user2,
    password=db_password2,
    database=db_database2)

cursor = conn.cursor()
# Load the driver data
cursor.execute("SELECT * FROM pedidos_modelo WHERE status = %s ", ("Entregado",))
result = cursor.fetchall()
# Create a list of column names
df = pd.DataFrame(result, columns=[desc[0] for desc in cursor.description])

# %%
# Merge the two DataFrames based on the 'Id' column
df_merged = pd.merge(df, df_comercios, left_on='id_comercio', right_on='id', how='left')
df_merged.head(5)
# Out:
#    id_pedido     status  id_cliente  id_comercio  id_repartidor  \
# 0         24  Entregado        1321          467             75
# 1         25  Entregado        8327          428            186
# 2         26  Entregado         656          791            294
# 3         27  Entregado        2882          103              2
# 4         28  Entregado        1383          132            155
#
#                              direccion_x     datetime_pedido fecha_entrega  \
# 0    Calle de Pablo Lafargue, 32, Madrid 2022-03-27 18:35:00    2022-03-27
# 1   Calle de Núñez de Balboa, 83, Madrid 2022-04-05 20:35:00    2022-04-05
# 2           Ronda de Segovia, 91, Madrid 2022-03-12 23:20:00    2022-03-12
# 3  Calle de Saavedra Fajardo, 10, Madrid 2022-03-16 21:20:00    2022-03-16
# 4       Calle de Alfonso XII, 19, Madrid 2022-04-02 23:35:00    2022-04-02
#
#   hora_entrega   id                 nombre   zona  \
# 0     18:35:00  467            Ciao Madrid  28004
# ...

# %%
import requests

# Define Google Maps API endpoint and parameters
endpoint = "https://maps.googleapis.com/maps/api/geocode/json"
params = {
    "latlng": "",
    "result_type": "neighborhood",
    "key": "AIzaSyCN0rUDiJWNFRbEXW2DX81j_kiS6_rUYzg"
}

# Create empty list to store results
neighborhoods = []

# Loop over coordinates and send requests to Google Maps API
for lat, lng in zip(df_merged["latitud"], df_merged["longitud"]):
    # Set latitude and longitude in parameters
    params["latlng"] = f"{lat},{lng}"

    # Send request to Google Maps API
    response = requests.get(endpoint, params=params)

    # Parse response to get neighborhood and add to list
    if response.ok:
        data = response.json()
        if data["results"]:
            neighborhood = data["results"][0]["address_components"][0]["long_name"]
            neighborhoods.append(neighborhood)
        else:
            neighborhoods.append(None)
    else:
        neighborhoods.append(None)

# Add neighborhoods list as a new column to df_merged
df_merged["zona"] = neighborhoods

# %%
df_merged = df_merged.assign(zona=df_merged["zona"])

# %%
df_merged.head(5)
# Out:
#    id_pedido     status  id_cliente  id_comercio  id_repartidor  \
# 0         24  Entregado        1321          467             75
# 1         25  Entregado        8327          428            186
# 2         26  Entregado         656          791            294
# 3         27  Entregado        2882          103              2
# 4         28  Entregado        1383          132            155
#
#                              direccion_x     datetime_pedido fecha_entrega  \
# 0    Calle de Pablo Lafargue, 32, Madrid 2022-03-27 18:35:00    2022-03-27
# 1   Calle de Núñez de Balboa, 83, Madrid 2022-04-05 20:35:00    2022-04-05
# 2           Ronda de Segovia, 91, Madrid 2022-03-12 23:20:00    2022-03-12
# 3  Calle de Saavedra Fajardo, 10, Madrid 2022-03-16 21:20:00    2022-03-16
# 4       Calle de Alfonso XII, 19, Madrid 2022-04-02 23:35:00    2022-04-02
#
#   hora_entrega   id                 nombre      zona  \
# 0     18:35:00  467            Ciao Madrid  Justicia
# ...

# %% [markdown]
# # Pedidos modelo2

# %%
import requests
def get_pedidos_modelo_api():
    # Use the requests library to send a GET request to the API endpoint and receive JSON data in response
    data = requests.get("https://eogwk5ap22.execute-api.eu-north-1.amazonaws.com/Dev/pedidos_modelo").json()

    # Create an empty list to store the formatted data
    pedidos_list = []

    # Loop through each dictionary in the received data and format it into a new dictionary with desired keys
    for char in data:
        dict_pedidos = {'id': char["id"],
                    'nombre': char["nombre"],
                    'zona': char["zona"],
                    'direccion': char["direccion"],
                    'tipo': char["tipo"],
                    'latitud': char["latitud"],
                    'longitud': char["longitud"]
                    }

        # Append the new dictionary to the list
        pedidos_list.append(dict_pedidos)

    # Return the list of formatted dictionaries
    return pedidos_list
# Create a pandas dataframe using data obtained from an API call to get driver information
df_pedidos_modelos = pd.DataFrame(get_pedidos_modelo_api())

# %%
pedidos_modelo_with_zona = pd.read_csv("pedidos_modelo_with_zona.csv") 
# Group the data by zona and count the records in each group
count_by_zona = pedidos_modelo_with_zona.groupby('zona').size().reset_index(name='count')

# Print the resulting DataFrame
print(count_by_zona)
# Out:
#                zona  count
# 0              AZCA     80
# 1          Abrantes     47
# 2           Almagro    568
# 3          Almenara     57
# 4       Almendrales     97
# ..              ...    ...
# 80        Trafalgar   1414
# 81       Valdemarín     39
# 82     Vallehermoso    245
# 83  Villaverde Alto     86
# 84     Vista Alegre    153
#
# [85 rows x 2 columns]

# %% [markdown]
# # Usando barrios.geojson en lugar de Google API apra obtener las zonas/neighborhoods

# %%
from folium.features import GeoJsonTooltip
import geopandas as gpd
pedidos_modelo_with_zona = pd.read_csv("pedidos_modelo_with_zona.csv") 
# Load the GeoJSON file
neighborhoods = gpd.read_file('barrios.geojson')

# Create a function to get the neighborhood name from a latitude and longitude pair
def get_neighborhood(latitude, longitude):
    point = Point(longitude, latitude)
    for index, row in neighborhoods.iterrows():
        if row['geometry'].contains(point):
            return row['nombre']

# Apply the function to the latitude and longitude columns in the DataFrame
pedidos_modelo_with_zona['neighborhood'] = pedidos_modelo_with_zona.apply(lambda row: get_neighborhood(row['latitud'], row['longitud']), axis=1)

# %%
pedidos_modelo_with_zona.to_csv("pedidos_modelo_with_zona2.csv", index=False)

# %%
import pandas as pd
count_by_zona = pd.read_csv('pedidos_modelo_with_zona2.csv')
count_by_zona = count_by_zona.groupby('zona').size().reset_index(name='count')
# Replace "AZCA" with "Azca" in the 'zona' column
count_by_zona['zona'] = count_by_zona['zona'].replace('AZCA', 'Azca')
count_by_zona.head(20)
# Out:
#                             zona  count
# 0                           Azca     80
# 1                       Abrantes     47
# 2                        Almagro    568
# 3                       Almenara     57
# 4                    Almendrales     97
# 5                         Aluche     56
# 6               Apostol Santiago     60
# 7                       Arapiles    499
# 8                        Aravaca    106
# 9                      Argüelles    814
# 10                       Atalaya     51
# 11           Barrio de La Latina   1997
# 12          Barrio de las Letras   3117
# 13                 Bellas Vistas     48
# 14                    Buenavista     42
# 15                    Campamento     56
# 16                      Canillas     87
# 17                    Canillejas     38
# 18                 Casa de Campo    337
# 19  Casco Histórico de Vicálvaro     61

# %% [markdown]
# # Añadiendo a barrios.geojson el caount de pedidos de cada zona

# %%
# Create a Pandas DataFrame with the count data
count_by = pd.read_csv('pedidos_modelo_with_zona2.csv')
count_by = count_by.groupby('neighborhood').size().reset_index(name='count')
# Replace "AZCA" with "Azca" in the 'zona' column
count_by['neighborhood'] = count_by['neighborhood'].replace('AZCA', 'Azca')
count_by= count_by_zona.rename(columns={'neighborhood': 'nombre'})
data = count_by_zona.groupby('nombre')['count'].sum().reset_index()

# %%
import pandas as pd
import json

# load barrios.geojson
with open('barrios.geojson') as f:
    geojson_data = json.load(f)

# load count_by_zona dataframe
count_by_zona

# iterate through each feature in geojson_data
for feature in geojson_data['features']:
    # get the nombre property value for the current feature
    nombre = feature['properties']['nombre']
    # find the corresponding row in count_by_zona dataframe
    row = count_by_zona[count_by_zona['nombre'] == nombre]
    # if the row exists, set the count property for the feature
    if not row.empty:
        feature['properties']['count'] = int(row['count'])


# Print the features with valid "count" values
for feature in geojson_data['features']:
    if 'count' in feature['properties']:
        count = feature['properties']['count']
        if isinstance(count, int):
            print(f"Name: {feature['properties']['nombre']}, Count: {count}")

# Write the updated GeoJSON data back to the file
with open('barrios2.geojson', 'w') as f:
    json.dump(geojson_data, f)
# Out:
# Name: Canillas, Count: 87
# Name: Casco Histórico de Vicálvaro, Count: 61
# Name: Cortes, Count: 6343
# Name: Rios Rosas, Count: 1020
# Name: Justicia, Count: 5285
# Name: Nueva España, Count: 46
# Name: Ibiza, Count: 756
# Name: Gaztambide, Count: 474
# Name: Argüelles, Count: 725
# Name: Trafalgar, Count: 1394
# Name: Almagro, Count: 679
# Name: Cuatro Caminos, Count: 363
# Name: Chopera, Count: 131
# Name: Imperial, Count: 235
# Name: Acacias, Count: 330
# Name: Almendrales, Count: 97
# Name: Palomas, Count: 44
# Name: Palacio, Count: 5972
# Name: Universidad, Count: 4590
# Name: Recoletos, Count: 1112
# Name: Puerta del Angel, Count: 331
# Name: La Paz, Count: 91
# Name: Goya, Count: 712
# Name: Embajadores, Count: 3526
# Name: Sol, Count: 9748
# Name: Legazpi, Count: 130
# Name: Delicias, Count: 408
# Name: Palos de Moguer, Count: 709
# Name: Atocha, Count: 44
# Name: Pacífico, Count: 272
# Name: Jerónimos, Count: 371
# Name: Guindalera, Count: 266
# Name: Lista, Count: 652
# ...

# %%
with open('barrios2.geojson') as f:
    geojson_data = json.load(f)
# Print the features with valid "count" values
for feature in geojson_data['features']:
    if 'count' in feature['properties']:
        count = feature['properties']['count']
        if isinstance(count, int):
            print(f"Name: {feature['properties']['nombre']}, Count: {count}")
# Out:
# Name: Canillas, Count: 87
# Name: Casco Histórico de Vicálvaro, Count: 61
# Name: Cortes, Count: 6343
# Name: Rios Rosas, Count: 1020
# Name: Justicia, Count: 5285
# Name: Nueva España, Count: 46
# Name: Ibiza, Count: 756
# Name: Gaztambide, Count: 474
# Name: Argüelles, Count: 725
# Name: Trafalgar, Count: 1394
# Name: Almagro, Count: 679
# Name: Cuatro Caminos, Count: 363
# Name: Chopera, Count: 131
# Name: Imperial, Count: 235
# Name: Acacias, Count: 330
# Name: Almendrales, Count: 97
# Name: Palomas, Count: 44
# Name: Palacio, Count: 5972
# Name: Universidad, Count: 4590
# Name: Recoletos, Count: 1112
# Name: Puerta del Angel, Count: 331
# Name: La Paz, Count: 91
# Name: Goya, Count: 712
# Name: Embajadores, Count: 3526
# Name: Sol, Count: 9748
# Name: Legazpi, Count: 130
# Name: Delicias, Count: 408
# Name: Palos de Moguer, Count: 709
# Name: Atocha, Count: 44
# Name: Pacífico, Count: 272
# Name: Jerónimos, Count: 371
# Name: Guindalera, Count: 266
# Name: Lista, Count: 652
# ...

# %% [markdown]
# # API para obtener ditancias y tiempos

# %%
import requests
def get_time_distance(origen_long, origen_lat, destin_long, destin_lat,*lugar):
    # Build the API request URL with the origin, destination, and API key
    url = "https://api.openrouteservice.org/v2/directions/driving-car?api_key=5b3ce3597851110001cf6248037ed40de1b6444ca5b189715abad70e&start={},{},&end={},{}".format(origen_long, origen_lat, destin_long, destin_lat)
    
    # Make the API request and parse the JSON response
    response = requests.get(url)
    data = json.loads(response.text)
    
    # Extract the distance and duration from the API response
    distance = data['features'][0]['properties']['segments'][0]['distance'] / 1000  # convert to kilometers
    duration = data['features'][0]['properties']['segments'][0]['duration'] / 60  # convert to minutes
    if lugar[0] == "tienda":
        messege = 'La distancia al lugar de recogida es de : {:.2f} kilometros'.format(distance),'La duración estimada del trayecto es de: {:.2f} minutos'.format(duration)
    else :
        messege = 'La distancia al lugar de entrega desde el punto de recogida es de : {:.2f} kilometros'.format(distance),'La duración estimada del trayecto es de: {:.2f} minutos'.format(duration)
    
    return messege


get_time_distance(-3,650346, 40,441461, 40,441461, 40,441461,"cliente")

# %%
import os
from pathlib import Path
import psycopg2
import pandas as pd
from datetime import datetime
import random
import requests
from sklearn.neighbors import NearestNeighbors
import numpy as np

# Get database credentials from environment variables
db_host2 = "appreparto-db.c0ttdmuj4kco.eu-north-1.rds.amazonaws.com"
db_user2 = "durumkebab"
db_password2 = "Qu3l3ch35353l5h4w4rm4!"
db_database2 = "repartos_test"

# Establish a connection to the database
conn = psycopg2.connect(
    host=db_host2,
    user=db_user2,
    password=db_password2,
    database=db_database2)

cursor = conn.cursor()
cursor.execute("UPDATE repartidores SET ocupado = %s WHERE id = %s ", (True, 8))
# Load the driver data
#cursor.execute("UPDATE clientes SET longitud = %s WHERE id = %s ", (-3.650345, 1))

# %%
cursor.execute("UPDATE pedidos SET status = %s , id_repartidor = %s  WHERE id_pedido = %s", ("Preparado",8, 823))

# %%
df_repartidores = pd.DataFrame(get_repartidores_api())
df_repartidores.head(20)
# Out:
#     id                          nombre  \
# 0    1             Cipriano Reig Galán
# 1    2             Lucas Salgado Leiva
# 2    3           Valentina Pol Estrada
# 3    4                   Gastón Varela
# 4    5     Guadalupe Iglesia Sarmiento
# 5    6         Milagros Adán Calatayud
# 6    7              César Barrio-Lucas
# 7    8           Ramiro Gonzalo Murcia
# 8    9                   Aura de López
# 9   10                Roxana Gallo Pla
# 10  11                Dionisia de Rosa
# 11  12       Maristela Royo Villalobos
# 12  13           Sebastian Vidal Benet
# 13  14               Julio del Carmona
# 14  15        Pacífica Castejón Tolosa
# 15  16        Goyo Tadeo Pomares Roman
# 16  17             Tomasa Baena Blanco
# 17  18  Francisco Javier Estrada Cerdá
# 18  19    Jennifer Perlita Jaume Juliá
# 19  20                 Carlota Aguilar
#
#                                       email status     vehiculo ocupado  zona  \
# ...

# %%
df_pedidos_recibidos = pd.DataFrame(get_repartidores_api())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df_pedidos_recibidos = pd.DataFrame(get_repartidores_api())
#
# Cell In[28], line 10, in get_repartidores_api()
#       8 # Loop through each driver in the retrieved data and extract the relevant information
#       9 for char in data:
# ---> 10     dict_repartidores = {'id': char["id"],
#      11                 'nombre': char["unombre"] if char["unombre"] else None,
#      12                 'email': char["email"] if char["email"] else None,
#      13                 'status': char["status"] if char["status"] else None,
#      14                 'vehiculo': char["vehiculo"] if char["vehiculo"] else None,
#      15                 'ocupado': char["ocupado"] if char["ocupado"] else None,
#      16                 'zona': char["zona"] if char["zona"] else None,
# ...

# %% [markdown]
# # Implementar modelo predictivo con mapa de zonas

# %% [markdown]
# ## Libraries

# %%
#Preparing folder variables
main_folder = os.path.abspath(os.path.join(os.pardir))
data_folder = (main_folder + "/" +"data")
raw_data = (data_folder + "/" + "raw_data")
processed_data = (data_folder + "/" + "processed_data")

# %% [markdown]
# ### geojson

# %%
import pandas as pd
import json

# load barrios.geojson
with open('barrios2.geojson') as f:
    geojson_data = json.load(f)
geojson_data
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-3.63693, 40.468875],
#        [-3.634108, 40.468605],
#        [-3.633838, 40.468622],
#        [-3.633668, 40.468661],
#        [-3.633597, 40.468677],
#        [-3.633397, 40.46877],
#        [-3.633107, 40.468902],
#        [-3.633063, 40.468898],
#        [-3.632944, 40.468888],
#        [-3.631246, 40.468739],
#        [-3.630124, 40.468635],
#        [-3.629939, 40.468598],
#        [-3.62762, 40.468142],
#        [-3.623579, 40.462637],
#        [-3.624599, 40.462638],
#        [-3.629654, 40.462639],
#        [-3.633266, 40.462673],
#        [-3.635381, 40.462691],
#        [-3.636239, 40.462687],
#        [-3.637269, 40.462686],
#        [-3.63759, 40.462652],
#        [-3.63789, 40.462601],
#        [-3.63814, 40.462545],
#        [-3.638439, 40.462464],
#        [-3.638748, 40.462359],
#        [-3.638904, 40.462282],
# ...

# %% [markdown]
# ## Pedidos from bd

# %%
import os
from pathlib import Path
import psycopg2
import pandas as pd

# %%
# Get database credentials from environment variables
db_host2 = "appreparto-db.c0ttdmuj4kco.eu-north-1.rds.amazonaws.com"
db_user2 = "durumkebab"
db_password2 = "Qu3l3ch35353l5h4w4rm4!"
db_database2 = "repartos_test"

# Establish a connection to the database
conn = psycopg2.connect(
    host=db_host2,
    user=db_user2,
    password=db_password2,
    database=db_database2)

# %%
# Establish a database connection and create a cursor object
cursor = conn.cursor()

# Load the driver data where status is "Entregado"
cursor.execute("SELECT * FROM pedidos_prediccion")

# Fetch all the results from the cursor
result = cursor.fetchall()

# Create a pandas dataframe from the query result with column names obtained from cursor description
df = pd.DataFrame(result, columns=[desc[0] for desc in cursor.description])

# create a copy of the df with different name
df_barrios = df.copy()

# %% [markdown]
# ## Getting barrio name from codigo postal

# %%
from geopy.geocoders import Nominatim

# Create an instance of Nominatim class for geocoding/reverse-geocoding
geolocator = Nominatim(user_agent=db_user2)

# Crea una nueva columna en el dataframe para almacenar el nombre del barrio correspondiente a cada código postal
df_barrios["barrio"] = ""

# Itera sobre cada código postal en la columna "zona" y obtiene el nombre del barrio correspondiente
for codigo_postal in df_barrios["zona"]:
    # Realiza una consulta de geocodificación para obtener la información de la ubicación
    location = geolocator.geocode({"postalcode": codigo_postal, "country": "Spain"})

    # Si se encontró una ubicación, obtiene el nombre del barrio y lo guarda en la columna "barrio" del dataframe
    if location:
        barrio = location.raw['display_name']
        # Separa la cadena por las comas y obtiene la primera palabra
        primer_palabra = barrio.split(',')[0]
        df_barrios.loc[df_barrios["zona"] == codigo_postal, "barrio"] = primer_palabra

# %%
df_barrios.head(5)
# Out:
#     zona  franja_horaria  total       fecha     barrio
# 0  28001               6      2  2022-03-31  Salamanca
# 1  28002               6      1  2022-03-31  Chamartín
# 2  28003               6      2  2022-03-31   Chamberí
# 3  28004               6      1  2022-03-31     Centro
# 4  28005               6      3  2022-03-31     Centro

# %% [markdown]
# ## Añadiendo a barrios.geojson el caount de pedidos de cada zona

# %%
# Create a Pandas DataFrame with the count data
count_by = pd.read_csv('pedidos_modelo_with_zona2.csv')
count_by = count_by.groupby('neighborhood').size().reset_index(name='count')
# Replace "AZCA" with "Azca" in the 'zona' column
count_by['neighborhood'] = count_by['neighborhood'].replace('AZCA', 'Azca')
count_by= count_by_zona.rename(columns={'neighborhood': 'nombre'})

# %%
import pandas as pd
import json

# load barrios.geojson
with open('barrios.geojson') as f:
    geojson_data = json.load(f)

# load count_by_zona dataframe
count_by_zona

# iterate through each feature in geojson_data
for feature in geojson_data['features']:
    # get the nombre property value for the current feature
    nombre = feature['properties']['nombre']
    # find the corresponding row in count_by_zona dataframe
    row = count_by_zona[count_by_zona['nombre'] == nombre]
    # if the row exists, set the count property for the feature
    if not row.empty:
        feature['properties']['count'] = int(row['count'])


# Print the features with valid "count" values
for feature in geojson_data['features']:
    if 'count' in feature['properties']:
        count = feature['properties']['count']
        if isinstance(count, int):
            print(f"Name: {feature['properties']['nombre']}, Count: {count}")

# Write the updated GeoJSON data back to the file
with open('barrios_count.geojson', 'w') as f:
    json.dump(geojson_data, f)
